# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf

pd.set_option("future.no_silent_downcasting", True)

# %%
oscars_summary = pd.read_csv("oscars_summary.csv")
acting_summary = pd.read_csv("acting_summary.csv")

# %% [markdown]
# # Linear Regression Analysis

# %%
# init model

m_ols1 = smf.ols("total_nominations ~ pct_words_m + pct_chars_m + avg_male_words", data=oscars_summary).fit()
print(m_ols1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      total_nominations   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     15.89
# Date:                Mon, 24 Nov 2025   Prob (F-statistic):           3.28e-10
# Time:                        12:06:47   Log-Likelihood:                -4008.4
# No. Observations:                1947   AIC:                             8025.
# Df Residuals:                    1943   BIC:                             8047.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -0.4868      0.214     -2.276      0.023      -0.906      -0.067
# ...

# %%
# male regplot

plt.figure(figsize=(10, 6))
sns.regplot(
    data=oscars_summary,
    x="num_characters_m",
    y="total_nominations",
    x_jitter=0.1,
    y_jitter=0.1,
    scatter_kws={"alpha": 0.25, "color": "steelblue"}
)

plt.title("Oscar Nominations (Non-Acting) vs Male Speaking Roles")
plt.xlabel("Number of Characters")
plt.ylabel("Nominations per Film")
plt.show()

# %%
# male reg mod, resids

ols2_X = sm.add_constant(oscars_summary["num_characters_m"])
ols2_y = oscars_summary["total_nominations"]

m_ols2 = sm.OLS(ols2_y, ols2_X).fit()
print(m_ols2.summary())

residuals = m_ols2.resid
fitted = m_ols2.fittedvalues

# Create diagnostic plots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Residuals vs Fitted
axes[0, 0].scatter(fitted, residuals)
axes[0, 0].axhline(0, color="black", linewidth=1)
axes[0, 0].set_title("Residuals vs. Fitted")
axes[0, 0].set_xlabel("Fitted Values")
axes[0, 0].set_ylabel("Residuals")

# 2. Histogram of residuals
axes[0, 1].hist(residuals, bins=40)
axes[0, 1].set_title("Residual Histogram")
axes[0, 1].set_xlabel("Residual")
axes[0, 1].set_ylabel("Frequency")

# 3. Q-Q plot
sm.qqplot(residuals, line="45", ax=axes[1, 0])
axes[1, 0].set_title("Q–Q Plot")

# 4. Scale–Location plot (sqrt(|residual|) vs fitted)
axes[1, 1].scatter(fitted, np.sqrt(np.abs(residuals)))
axes[1, 1].set_title("Scale–Location Plot")
axes[1, 1].set_xlabel("Fitted Values")
axes[1, 1].set_ylabel("√|Residual|")

plt.tight_layout()
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      total_nominations   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     96.52
# Date:                Mon, 24 Nov 2025   Prob (F-statistic):           2.88e-22
# Time:                        12:08:52   Log-Likelihood:                -3984.9
# No. Observations:                1947   AIC:                             7974.
# Df Residuals:                    1945   BIC:                             7985.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0440      0.098      0.451      0.652      -0.147       0.235
# ...

# %%
# female regplot

plt.figure(figsize=(10, 6))
sns.regplot(
    data=oscars_summary,
    x="num_characters_f",
    y="total_nominations",
    x_jitter=0.1,
    y_jitter=0.1,
    scatter_kws={"alpha": 0.25, "color": "lightcoral"},
    line_kws={"color": "darkred"}
)

plt.xlim(-2, 32)
plt.title("Oscar Nominations (Non-Acting) vs Female Speaking Roles")
plt.xlabel("Number of Characters")
plt.ylabel("Nominations per Film")
plt.show()

# %%
# female reg mod, resids

fols_X = sm.add_constant(oscars_summary["num_characters_f"])
fols_y = oscars_summary["total_nominations"]

f_ols1 = sm.OLS(fols_y, fols_X).fit()
print(f_ols1.summary())

residuals = f_ols1.resid
fitted = f_ols1.fittedvalues

# Create diagnostic plots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Residuals vs Fitted
axes[0, 0].scatter(fitted, residuals)
axes[0, 0].axhline(0, color="black", linewidth=1)
axes[0, 0].set_title("Residuals vs. Fitted")
axes[0, 0].set_xlabel("Fitted Values")
axes[0, 0].set_ylabel("Residuals")

# 2. Histogram of residuals
axes[0, 1].hist(residuals, bins=40)
axes[0, 1].set_title("Residual Histogram")
axes[0, 1].set_xlabel("Residual")
axes[0, 1].set_ylabel("Frequency")

# 3. Q-Q plot
sm.qqplot(residuals, line="45", ax=axes[1, 0])
axes[1, 0].set_title("Q–Q Plot")

# 4. Scale–Location plot (sqrt(|residual|) vs fitted)
axes[1, 1].scatter(fitted, np.sqrt(np.abs(residuals)))
axes[1, 1].set_title("Scale–Location Plot")
axes[1, 1].set_xlabel("Fitted Values")
axes[1, 1].set_ylabel("√|Residual|")

plt.tight_layout()
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      total_nominations   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     4.941
# Date:                Mon, 24 Nov 2025   Prob (F-statistic):             0.0263
# Time:                        12:09:00   Log-Likelihood:                -4029.6
# No. Observations:                1947   AIC:                             8063.
# Df Residuals:                    1945   BIC:                             8074.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.0632      0.083     12.871      0.000       0.901       1.225
# ...

# %%
# overdispersion check

print((oscars_summary["total_nominations"] == 0).mean())
oscars_summary["total_nominations"].var(), oscars_summary["total_nominations"].mean()
# Out:
# 0.7077555213148433
# (3.685597944712597, 0.9070364663585002)

# %% [markdown]
# # Negative Binomial Regression Analysis

# %%
# all noms ~ chars mod, resid

nb1_y = oscars_summary["total_nominations"]
nb1_X = sm.add_constant(oscars_summary[["num_characters_m", "num_characters_f"]])

model_nb1 = sm.NegativeBinomial(nb1_y, nb1_X).fit()
print(model_nb1.summary())

resid_pearson = model_nb1.resid_pearson
fitted = model_nb1.fittedvalues

plt.scatter(fitted, resid_pearson, alpha=0.5)
plt.axhline(0, color="black")
plt.xlabel("Fitted values")
plt.ylabel("Pearson residuals")
plt.title("Residuals vs Fitted")
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.164782
#          Iterations: 12
#          Function evaluations: 17
#          Gradient evaluations: 17
#                      NegativeBinomial Regression Results
# ...
# Dep. Variable:      total_nominations   No. Observations:                 1947
# Model:               NegativeBinomial   Df Residuals:                     1944
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 24 Nov 2025   Pseudo R-squ.:                 0.01320
# Time:                        12:12:38   Log-Likelihood:                -2267.8
# converged:                       True   LL-Null:                       -2298.2
# Covariance Type:            nonrobust   LLR p-value:                 6.694e-14
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
# oscars_summary["fchar_year"] = oscars_summary["num_characters_f"] * oscars_summary["year"]
# oscars_summary["mchar_year"] = oscars_summary["num_characters_m"] * oscars_summary["year"]

# nb1b_y = oscars_summary["total_nominations"]
# nb1b_X = sm.add_constant(oscars_summary[["ncf2", "ncm2"]])

# model_nb1b = sm.NegativeBinomial(nb1b_y, nb1b_X).fit()
# print(model_nb1b.summary())

# resid_pearson = model_nb1b.resid_pearson
# fitted = model_nb1b.fittedvalues

# plt.scatter(fitted, resid_pearson, alpha=0.5)
# plt.axhline(0, color="black")
# plt.xlabel("Fitted values")
# plt.ylabel("Pearson residuals")
# plt.title("Residuals vs Fitted")
# plt.show()

# model_nb1b = smf.glm(
#     "total_nominations ~ bs(year, df=6) + num_characters_m + num_characters_f",
#     data=oscars_summary,
#     family=sm.families.NegativeBinomial()
# ).fit()

# print(model_nb1b.summary())

# resid_pearson = model_nb1b.resid_pearson
# fitted = model_nb1b.fittedvalues

# plt.scatter(fitted, resid_pearson, alpha=0.5)
# plt.axhline(0, color="black")
# plt.xlabel("Fitted values")
# plt.ylabel("Pearson residuals")
# plt.title("Residuals vs Fitted")
# plt.show()

# %%
# all wins ~ chars mod, resid

nb2_y = oscars_summary["total_wins"]
nb2_X = sm.add_constant(oscars_summary[["num_characters_m", "num_characters_f"]])

model_nb2 = sm.NegativeBinomial(nb2_y, nb2_X).fit()
print(model_nb2.summary())

resid_pearson = model_nb2.resid_pearson
fitted = model_nb2.fittedvalues

plt.scatter(fitted, resid_pearson, alpha=0.5)
plt.axhline(0, color="black")
plt.xlabel("Fitted values")
plt.ylabel("Pearson residuals")
plt.title("Residuals vs Fitted")
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.500344
#          Iterations: 18
#          Function evaluations: 24
#          Gradient evaluations: 24
#                      NegativeBinomial Regression Results
# ...
# Dep. Variable:             total_wins   No. Observations:                 1947
# Model:               NegativeBinomial   Df Residuals:                     1944
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 24 Nov 2025   Pseudo R-squ.:                 0.02013
# Time:                        12:28:17   Log-Likelihood:                -974.17
# converged:                       True   LL-Null:                       -994.18
# Covariance Type:            nonrobust   LLR p-value:                 2.034e-09
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Logistic Regression Analysis

# %%
# actor noms ~ pct words mod
bn_m1_y = acting_summary["actor_nom"].astype(int)
bn_m1_X = sm.add_constant(acting_summary[["pct_words_m", "pct_words_f"]])
bn_m1 = sm.GLM(bn_m1_y, bn_m1_X, family=sm.families.Binomial()).fit()
print(bn_m1.summary())

# resid
plt.scatter(bn_m1.fittedvalues, bn_m1.resid_pearson)
plt.axhline(0, color='black')
plt.xlabel("Fitted values")
plt.ylabel("Pearson residuals")
plt.title("Pearson Residuals vs Fitted")
plt.show()

# binned Pearson resid
bins = pd.qcut(bn_m1.fittedvalues, q=20, duplicates="drop")
binned = bn_m1.resid_pearson.groupby(bins, observed=False).mean()
centers = bn_m1.fittedvalues.groupby(bins, observed=False).mean()
plt.scatter(centers, binned)
plt.axhline(0, color='black')
plt.xlabel("Average fitted probability")
plt.ylabel("Average Pearson residual (binned)")
plt.title("Binned Residual Plot (Linearity Check)")
plt.show()

# bn_m2_y = acting_summary["actor_win"].astype(int)
# bn_m2_X = acting_summary[["pct_words_m", "pct_words_f"]]
# bn_m2_X = sm.add_constant(bn_m2_X)
# bn_m2 = sm.GLM(bn_m2_y, bn_m2_X, family=sm.families.Binomial()).fit()
# print(bn_m2.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              actor_nom   No. Observations:                  315
# Model:                            GLM   Df Residuals:                      313
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -126.73
# Date:                Mon, 24 Nov 2025   Deviance:                       253.47
# Time:                        18:41:39   Pearson chi2:                     314.
# No. Iterations:                    23   Pseudo R-squ. (CS):             0.3356
# Covariance Type:            nonrobust
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.3505      0.142     -2.474      0.013      -0.628      -0.073
# ...

# %%
from patsy import bs

# actor noms ~ pct words spline mod
bnm_spline = smf.glm(
    formula="actor_nom ~ bs(pct_words_f, df=4) + bs(pct_words_m, df=4)",
    data=acting_summary,
    family=sm.families.Binomial()
).fit()

print(bnm_spline.summary())

# resid
plt.scatter(bnm_spline.fittedvalues, bnm_spline.resid_pearson)
plt.axhline(0, color='black')
plt.xlabel("Fitted values")
plt.ylabel("Pearson residuals")
plt.title("Pearson Residuals vs Fitted")
plt.show()

# binned Pearson resid
bins = pd.qcut(bnm_spline.fittedvalues, q=20, duplicates="drop")
binned = bnm_spline.resid_pearson.groupby(bins, observed=False).mean()
centers = bnm_spline.fittedvalues.groupby(bins, observed=False).mean()
plt.scatter(centers, binned)
plt.axhline(0, color='black')
plt.xlabel("Average fitted probability")
plt.ylabel("Average Pearson residual (binned)")
plt.title("Binned Residual Plot with Spline Model")
plt.show()
# Out:
#                             Generalized Linear Model Regression Results
# ...
# Dep. Variable:     ['actor_nom[False]', 'actor_nom[True]']   No. Observations:                  315
# Model:                                                 GLM   Df Residuals:                      310
# Model Family:                                     Binomial   Df Model:                            4
# Link Function:                                       Logit   Scale:                          1.0000
# Method:                                               IRLS   Log-Likelihood:                -126.67
# Date:                                     Mon, 24 Nov 2025   Deviance:                       253.34
# Time:                                             13:20:48   Pearson chi2:                     310.
# No. Iterations:                                        100   Pseudo R-squ. (CS):             0.3359
# Covariance Type:                                 nonrobust
# ...

# %%
# actor noms ~ pct words spline interaction mod

# Choose degrees of freedom for each spline
df_spline = 4

# Formula: main effects + interaction via multiplication of spline bases
formula = (
    f"actor_nom ~ bs(pct_words_f, df={df_spline})"
    f" + bs(pct_words_m, df={df_spline})"
    f" + bs(pct_words_f, df={df_spline}):bs(pct_words_m, df={df_spline})"
)

spline_int = smf.glm(
    formula=formula,
    data=acting_summary,
    family=sm.families.Binomial()
).fit()

print(spline_int.summary())

# resid
plt.scatter(spline_int.fittedvalues, spline_int.resid_pearson)
plt.axhline(0, color='black')
plt.xlabel("Fitted values")
plt.ylabel("Pearson residuals")
plt.title("Pearson Residuals vs Fitted")
plt.show()

# binned Peason resid
bins = pd.qcut(spline_int.fittedvalues, 50, duplicates='drop')
binned_resid = spline_int.resid_pearson.groupby(bins, observed=False).mean()
binned_center = spline_int.fittedvalues.groupby(bins, observed=False).mean()

plt.scatter(binned_center, binned_resid)
plt.axhline(0, color='black')
plt.xlabel("Average fitted probability")
plt.ylabel("Average Pearson residual (binned)")
plt.title("Binned Residual Plot (Spline Interaction Model)")
plt.show()
# Out:
#                             Generalized Linear Model Regression Results
# ...
# Dep. Variable:     ['actor_nom[False]', 'actor_nom[True]']   No. Observations:                  315
# Model:                                                 GLM   Df Residuals:                      304
# Model Family:                                     Binomial   Df Model:                           10
# Link Function:                                       Logit   Scale:                          1.0000
# Method:                                               IRLS   Log-Likelihood:                -124.70
# Date:                                     Mon, 24 Nov 2025   Deviance:                       249.40
# Time:                                             13:25:02   Pearson chi2:                     301.
# No. Iterations:                                        100   Pseudo R-squ. (CS):             0.3441
# Covariance Type:                                 nonrobust
# ...

# %%
# actress noms ~ pct words mod, resid

bn_f1_y = acting_summary["actress_nom"].astype(int)
bn_f1_X = sm.add_constant(acting_summary[["pct_words_f", "pct_words_m"]])

bn_f1 = sm.GLM(bn_f1_y, bn_f1_X, family=sm.families.Binomial()).fit()
print(bn_f1.summary())

plt.scatter(bn_f1.fittedvalues, bn_f1.resid_pearson)
plt.axhline(0, color='black')
plt.xlabel("Fitted values")
plt.ylabel("Pearson residuals")
plt.title("Pearson Residuals vs Fitted")
plt.show()

# binned Pearson resid
bins = pd.qcut(bn_f1.fittedvalues, q=20, duplicates="drop")
binned = bn_f1.resid_pearson.groupby(bins, observed=False).mean()
centers = bn_f1.fittedvalues.groupby(bins, observed=False).mean()
plt.scatter(centers, binned)
plt.axhline(0, color='black')
plt.xlabel("Average fitted probability")
plt.ylabel("Average Pearson residual (binned)")
plt.title("Binned Residual Plot (Linearity Check)")
plt.show()

# bn_f2_y = acting_summary["actress_win"].astype(int)
# bn_f2_X = acting_summary[["pct_words_f", "pct_words_m"]]
# bn_f2_X = sm.add_constant(bn_f2_X)
# bn_f2 = sm.GLM(bn_f2_y, bn_f2_X, family=sm.families.Binomial()).fit()
# print(bn_f2.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            actress_nom   No. Observations:                  315
# Model:                            GLM   Df Residuals:                      313
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -151.49
# Date:                Mon, 24 Nov 2025   Deviance:                       302.97
# Time:                        18:42:55   Pearson chi2:                     323.
# No. Iterations:                    52   Pseudo R-squ. (CS):             0.3298
# Covariance Type:            nonrobust
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           1.7367      0.229      7.587      0.000       1.288       2.185
# ...

# %%
# Coefficients from your logistic regression models
# Actress nominations
intercept_actress = 1.7367
coef_f_actress = 5.3997
coef_m_actress = -3.6630

# Actor nominations
intercept_actor = -0.3505
coef_f_actor = -4.3258
coef_m_actor = 3.9753

# Generate pct_words_f from 0 to 1
pct_words_f = np.linspace(0, 1, 101)
pct_words_m = 1 - pct_words_f  # Because they sum to 1

# Compute logit for actress
logit_actress = intercept_actress + coef_f_actress*pct_words_f + coef_m_actress*pct_words_m
prob_actress = 1 / (1 + np.exp(-logit_actress))

# Compute logit for actor
logit_actor = intercept_actor + coef_f_actor*pct_words_f + coef_m_actor*pct_words_m
prob_actor = 1 / (1 + np.exp(-logit_actor))

# Plot
plt.figure(figsize=(10,6))
plt.plot(pct_words_f*100, prob_actress, label='Actress Nomination', color='coral', linewidth=2)
plt.plot(pct_words_f*100, prob_actor, label='Actor Nomination', color='steelblue', linewidth=2)
plt.axvline(50, color='gray', linestyle='--', alpha=0.5)
plt.scatter(50, 0.932, color='coral')  # 50% female dialogue actress probability
plt.scatter(50, 0.371, color='steelblue')  # 50% female dialogue actor probability

plt.xlabel('Percentage of Dialogue Spoken by Female Characters (%)', fontsize=12)
plt.ylabel('Predicted Probability of Nomination', fontsize=12)
plt.title('Predicted Probability of Actor vs Actress Nominations by Dialogue Allocation', fontsize=14)
plt.legend()
plt.grid(alpha=0.3)
plt.ylim(0, 1)
plt.show()

# %%
# number of films in the dataset with over 50% male dialogue
num_films_over_50_male_dialogue = (acting_summary["pct_words_m"] > 0.5).sum()
num_films_over_50_female_dialogue = (acting_summary["pct_words_f"] > 0.5).sum()
print(num_films_over_50_male_dialogue, num_films_over_50_female_dialogue)
# Out:
# 257 57
